# %% [markdown]
# # CNN - Shufflenet - Transfer Learning

# %%
import os
import pandas as pd
import numpy as np
import time

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim


import matplotlib.pyplot as plt

from torchvision import models
from torchinfo import summary
from torchvision import datasets, transforms
from torch.utils.data import random_split, DataLoader, Dataset
from torchmetrics.classification import MulticlassConfusionMatrix, MulticlassPrecision, MulticlassRecall, MulticlassF1Score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# ## Loading Dataset

# %%
path = os.path.realpath('data/animal_10')
list_path = path.split('/')
list_path.remove('animal_cnn')
list_path.remove('animal-project')
path_training = os.path.join('/'.join(list_path), 'raw-img_training')
path_training
# Out:
# '/home/viviane/projects/data/animal_10/raw-img_training'

# %%
dataset = datasets.ImageFolder(
    root=path_training, 
    transform=transforms.ToTensor()
)
classes = dataset.classes
print(classes)
# Out:
# ['butterfly', 'cat', 'cow', 'dog', 'elephant', 'hen', 'horse', 'sheep', 'spider', 'squirrel']

# %%
path = os.path.realpath('data/animal_10')
list_path = path.split('/')
list_path.remove('animal_cnn')
list_path.remove('animal-project')
path_val = os.path.join('/'.join(list_path), 'raw_img_test')
path_val
# Out:
# '/home/viviane/projects/data/animal_10/raw_img_test'

# %%
train_dir = path_training
val_dir = path_val

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 16

# %% [markdown]
# ## Preprocessing

# %%
# Define data augmentation for the training dataset
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(IMAGE_SIZE),   # Random crop and resize
    transforms.RandomHorizontalFlip(p=0.5),     # Random horizontal flip
    transforms.RandomRotation(20),              # Random rotation within ±20 degrees
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=0, shear=10, scale=(0.8, 1.2)),  # Shearing
    transforms.ToTensor(),                      # Convert to tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) # Normalize
])

# Define validation dataset - no augmentation, only resizing and normalization
val_transforms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])


# split train_dataset and load
train_dataset = torchvision.datasets.ImageFolder(root=train_dir, transform=train_transforms)
val_dataset = torchvision.datasets.ImageFolder(root=val_dir, transform=val_transforms)

train_size = int(0.8 * len(train_dataset))  # 80% for training
test_size = len(train_dataset) - train_size  # Remaining for testing

train_dataset, test_dataset = random_split(train_dataset, [train_size, test_size])

# Define loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f'Training samples: {len(train_dataset)}, Test samples: {len(test_dataset)}, Validation samples: {len(val_dataset)}')
# Out:
# Training samples: 10472, Test samples: 2619, Validation samples: 13091

# %%
print(f'Training samples: {len(train_loader)}, Test samples: {len(test_loader)}, Validation samples: {len(val_loader)}')
# Out:
# Training samples: 655, Test samples: 164, Validation samples: 819

# %% [markdown]
# ## Architecture

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 10

model = models.shufflenet_v2_x2_0(weights='IMAGENET1K_V1') 
model.fc = nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

print(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/shufflenetv2_x2_0-8be3c8ee.pth" to /home/viviane/.cache/torch/hub/checkpoints/shufflenetv2_x2_0-8be3c8ee.pth
#
# 00.0%
# ShuffleNetV2(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (stage2): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(24, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(24, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(122, 122, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=122, bias=False)
#         (4): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(122, 122, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=122, bias=False)
#         (4): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(122, 122, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=122, bias=False)
#         (4): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(122, 122, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=122, bias=False)
#         (4): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage3): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=244, bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (4): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (5): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (6): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (7): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage4): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=488, bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(488, 488, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=488, bias=False)
#         (4): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(488, 488, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=488, bias=False)
#         (4): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(488, 488, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=488, bias=False)
#         (4): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(488, 488, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=488, bias=False)
#         (4): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (conv5): Sequential(
#     (0): Conv2d(976, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
summary(model, input_size=(BATCH_SIZE, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ShuffleNetV2                             [16, 10]                  --
# ├─Sequential: 1-1                        [16, 24, 112, 112]        --
# │    └─Conv2d: 2-1                       [16, 24, 112, 112]        648
# │    └─BatchNorm2d: 2-2                  [16, 24, 112, 112]        48
# │    └─ReLU: 2-3                         [16, 24, 112, 112]        --
# ├─MaxPool2d: 1-2                         [16, 24, 56, 56]          --
# ├─Sequential: 1-3                        [16, 244, 28, 28]         --
# │    └─InvertedResidual: 2-4             [16, 244, 28, 28]         --
# │    │    └─Sequential: 3-1              [16, 122, 28, 28]         3,436
# │    │    └─Sequential: 3-2              [16, 122, 28, 28]         19,642
# │    └─InvertedResidual: 2-5             [16, 244, 28, 28]         --
# │    │    └─Sequential: 3-3              [16, 122, 28, 28]         31,598
# │    └─InvertedResidual: 2-6             [16, 244, 28, 28]         --
# │    │    └─Sequential: 3-4              [16, 122, 28, 28]         31,598
# │    └─InvertedResidual: 2-7             [16, 244, 28, 28]         --
# │    │    └─Sequential: 3-5              [16, 122, 28, 28]         31,598
# ├─Sequential: 1-4                        [16, 488, 14, 14]         --
# │    └─InvertedResidual: 2-8             [16, 488, 14, 14]         --
# │    │    └─Sequential: 3-6              [16, 244, 14, 14]         62,708
# │    │    └─Sequential: 3-7              [16, 244, 14, 14]         122,732
# │    └─InvertedResidual: 2-9             [16, 488, 14, 14]         --
# │    │    └─Sequential: 3-8              [16, 244, 14, 14]         122,732
# │    └─InvertedResidual: 2-10            [16, 488, 14, 14]         --
# │    │    └─Sequential: 3-9              [16, 244, 14, 14]         122,732
# │    └─InvertedResidual: 2-11            [16, 488, 14, 14]         --
# │    │    └─Sequential: 3-10             [16, 244, 14, 14]         122,732
# │    └─InvertedResidual: 2-12            [16, 488, 14, 14]         --
# │    │    └─Sequential: 3-11             [16, 244, 14, 14]         122,732
# │    └─InvertedResidual: 2-13            [16, 488, 14, 14]         --
# │    │    └─Sequential: 3-12             [16, 244, 14, 14]         122,732
# │    └─InvertedResidual: 2-14            [16, 488, 14, 14]         --
# │    │    └─Sequential: 3-13             [16, 244, 14, 14]         122,732
# │    └─InvertedResidual: 2-15            [16, 488, 14, 14]         --
# │    │    └─Sequential: 3-14             [16, 244, 14, 14]         122,732
# ├─Sequential: 1-5                        [16, 976, 7, 7]           --
# │    └─InvertedResidual: 2-16            [16, 976, 7, 7]           --
# │    │    └─Sequential: 3-15             [16, 488, 7, 7]           244,488
# │    │    └─Sequential: 3-16             [16, 488, 7, 7]           483,608
# │    └─InvertedResidual: 2-17            [16, 976, 7, 7]           --
# │    │    └─Sequential: 3-17             [16, 488, 7, 7]           483,608
# │    └─InvertedResidual: 2-18            [16, 976, 7, 7]           --
# │    │    └─Sequential: 3-18             [16, 488, 7, 7]           483,608
# │    └─InvertedResidual: 2-19            [16, 976, 7, 7]           --
# │    │    └─Sequential: 3-19             [16, 488, 7, 7]           483,608
# ├─Sequential: 1-6                        [16, 2048, 7, 7]          --
# │    └─Conv2d: 2-20                      [16, 2048, 7, 7]          1,998,848
# │    └─BatchNorm2d: 2-21                 [16, 2048, 7, 7]          4,096
# │    └─ReLU: 2-22                        [16, 2048, 7, 7]          --
# ├─Linear: 1-7                            [16, 10]                  20,490
# ==========================================================================================
# Total params: 5,365,486
# Trainable params: 5,365,486
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 9.30
# ==========================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 958.46
# Params size (MB): 21.46
# Estimated Total Size (MB): 989.56
# ==========================================================================================

# %%
## Training

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    # Metrics
    confusion_matrix = MulticlassConfusionMatrix(num_classes=10)
    precision = MulticlassPrecision(num_classes=10, average='macro')
    recall = MulticlassRecall(num_classes=10, average='macro')
    f1_score = MulticlassF1Score(num_classes=10, average='macro')

    for epoch in range(num_epochs):
        # Training
        model.train()
        train_loss = 0.0
        correct_train = 0
        total_train = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Clear gradients
            optimizer.zero_grad()

            # feed foward
            outputs = model(inputs)
            
            # Compute loss using cross entropy
            loss = criterion(outputs, labels)

            # backpropagation
            loss.backward()

            # Update weights
            optimizer.step()
            
            # Update results
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (preds == labels).sum().item()

        train_losses.append(train_loss / len(train_loader))
        train_accuracies.append(100 * correct_train / total_train)

        # Evaluation part to print metrics for each epoch
        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0

        all_preds = []
        all_labels = []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, preds = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (preds == labels).sum().item()

                # For metrics
                all_preds.append(preds.cpu())
                all_labels.append(labels.cpu())

        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(100 * correct_val / total_val)

        
        all_preds = torch.cat(all_preds)
        all_labels = torch.cat(all_labels)

        
        precision_value = precision(all_preds, all_labels)
        recall_value = recall(all_preds, all_labels)
        f1_value = f1_score(all_preds, all_labels)
        conf_matrix = confusion_matrix(all_preds, all_labels)

        
        print(f"Epoch {epoch + 1}/{num_epochs}")
        print(f"Train Loss: {train_losses[-1]:.4f} | Train Acc: {train_accuracies[-1]:.2f}%")
        print(f"Val Loss: {val_losses[-1]:.4f} | Val Acc: {val_accuracies[-1]:.2f}%")
        print(f"Precision: {precision_value:.4f} | Recall: {recall_value:.4f} | F1 Score: {f1_value:.4f}\n")

    return train_losses, val_losses, train_accuracies, val_accuracies, conf_matrix

# %%
t1 = time.time()
print(f"Using device: {device}")

train_losses, val_losses, train_accuracies, val_accuracies, conf_matrix = train_model(
    model, train_loader, test_loader, criterion, optimizer, num_epochs=50)

print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Using device: cuda
# Epoch 1/50
# Train Loss: 1.0850 | Train Acc: 64.01%
# Val Loss: 0.9810 | Val Acc: 68.92%
# Precision: 0.6935 | Recall: 0.6618 | F1 Score: 0.6560
#
# Epoch 2/50
# Train Loss: 0.9278 | Train Acc: 69.32%
# Val Loss: 0.8612 | Val Acc: 72.51%
# Precision: 0.7753 | Recall: 0.6778 | F1 Score: 0.7086
#
# Epoch 3/50
# Train Loss: 0.8357 | Train Acc: 72.49%
# Val Loss: 0.7720 | Val Acc: 74.11%
# Precision: 0.7344 | Recall: 0.7335 | F1 Score: 0.7297
#
# Epoch 4/50
# Train Loss: 0.7597 | Train Acc: 74.92%
# Val Loss: 0.7204 | Val Acc: 76.63%
# Precision: 0.7549 | Recall: 0.7472 | F1 Score: 0.7452
#
# Epoch 5/50
# Train Loss: 0.7468 | Train Acc: 75.02%
# Val Loss: 0.6538 | Val Acc: 78.92%
# Precision: 0.7862 | Recall: 0.7734 | F1 Score: 0.7767
#
# Epoch 6/50
# Train Loss: 0.6944 | Train Acc: 77.14%
# Val Loss: 0.6741 | Val Acc: 77.89%
# Precision: 0.7666 | Recall: 0.7652 | F1 Score: 0.7654
#
# Epoch 7/50
# Train Loss: 0.6697 | Train Acc: 77.78%
# Val Loss: 0.7435 | Val Acc: 76.75%
# Precision: 0.7666 | Recall: 0.7563 | F1 Score: 0.7538
#
# Epoch 8/50
# Train Loss: 0.6788 | Train Acc: 77.59%
# Val Loss: 0.6649 | Val Acc: 78.43%
# Precision: 0.7918 | Recall: 0.7679 | F1 Score: 0.7750
#
# Epoch 9/50
# Train Loss: 0.6275 | Train Acc: 79.20%
# Val Loss: 0.6531 | Val Acc: 77.40%
# Precision: 0.7725 | Recall: 0.7608 | F1 Score: 0.7622
#
# Epoch 10/50
# Train Loss: 0.6165 | Train Acc: 79.62%
# Val Loss: 0.6518 | Val Acc: 78.66%
# Precision: 0.8149 | Recall: 0.7562 | F1 Score: 0.7776
#
# Epoch 11/50
# Train Loss: 0.5907 | Train Acc: 80.34%
# Val Loss: 0.6570 | Val Acc: 80.03%
# Precision: 0.8178 | Recall: 0.7785 | F1 Score: 0.7927
#
# Epoch 12/50
# Train Loss: 0.5947 | Train Acc: 80.19%
# Val Loss: 0.6502 | Val Acc: 78.50%
# Precision: 0.7850 | Recall: 0.7660 | F1 Score: 0.7713
#
# Epoch 13/50
# Train Loss: 0.5804 | Train Acc: 80.57%
# Val Loss: 0.6541 | Val Acc: 80.68%
# Precision: 0.8026 | Recall: 0.7940 | F1 Score: 0.7950
#
# Epoch 14/50
# Train Loss: 0.5596 | Train Acc: 81.07%
# Val Loss: 0.5756 | Val Acc: 80.53%
# Precision: 0.8229 | Recall: 0.7803 | F1 Score: 0.7968
#
# Epoch 15/50
# Train Loss: 0.5411 | Train Acc: 82.24%
# Val Loss: 0.6276 | Val Acc: 80.03%
# Precision: 0.8047 | Recall: 0.7874 | F1 Score: 0.7932
#
# Epoch 16/50
# Train Loss: 0.5474 | Train Acc: 81.67%
# Val Loss: 0.6153 | Val Acc: 80.18%
# Precision: 0.8037 | Recall: 0.7815 | F1 Score: 0.7897
#
# Epoch 17/50
# Train Loss: 0.5431 | Train Acc: 81.55%
# Val Loss: 0.6035 | Val Acc: 80.15%
# Precision: 0.8120 | Recall: 0.7816 | F1 Score: 0.7932
#
# Epoch 18/50
# Train Loss: 0.5182 | Train Acc: 82.41%
# Val Loss: 0.5691 | Val Acc: 80.83%
# Precision: 0.8129 | Recall: 0.7850 | F1 Score: 0.7962
#
# Epoch 19/50
# Train Loss: 0.5090 | Train Acc: 82.68%
# Val Loss: 0.6239 | Val Acc: 80.15%
# Precision: 0.8059 | Recall: 0.7788 | F1 Score: 0.7891
#
# Epoch 20/50
# Train Loss: 0.4967 | Train Acc: 83.46%
# Val Loss: 0.5151 | Val Acc: 83.20%
# Precision: 0.8390 | Recall: 0.8127 | F1 Score: 0.8243
#
# Epoch 21/50
# Train Loss: 0.5188 | Train Acc: 82.56%
# Val Loss: 0.5558 | Val Acc: 81.71%
# Precision: 0.8081 | Recall: 0.8123 | F1 Score: 0.8067
#
# Epoch 22/50
# Train Loss: 0.5043 | Train Acc: 82.99%
# Val Loss: 0.5875 | Val Acc: 81.48%
# Precision: 0.8184 | Recall: 0.7965 | F1 Score: 0.8061
#
# Epoch 23/50
# Train Loss: 0.4837 | Train Acc: 83.86%
# Val Loss: 0.5179 | Val Acc: 83.77%
# Precision: 0.8398 | Recall: 0.8245 | F1 Score: 0.8299
#
# Epoch 24/50
# Train Loss: 0.4762 | Train Acc: 84.09%
# Val Loss: 0.5541 | Val Acc: 81.75%
# Precision: 0.8215 | Recall: 0.8078 | F1 Score: 0.8092
#
# Epoch 25/50
# Train Loss: 0.4706 | Train Acc: 84.31%
# Val Loss: 0.5257 | Val Acc: 83.31%
# Precision: 0.8370 | Recall: 0.8185 | F1 Score: 0.8263
#
# Epoch 26/50
# Train Loss: 0.4519 | Train Acc: 84.74%
# Val Loss: 0.5217 | Val Acc: 82.59%
# Precision: 0.8321 | Recall: 0.8039 | F1 Score: 0.8139
#
# Epoch 27/50
# Train Loss: 0.4483 | Train Acc: 85.43%
# Val Loss: 0.5080 | Val Acc: 83.58%
# Precision: 0.8319 | Recall: 0.8296 | F1 Score: 0.8300
#
# Epoch 28/50
# Train Loss: 0.4331 | Train Acc: 85.08%
# Val Loss: 0.5321 | Val Acc: 83.66%
# Precision: 0.8497 | Recall: 0.8171 | F1 Score: 0.8310
#
# Epoch 29/50
# Train Loss: 0.4503 | Train Acc: 84.59%
# Val Loss: 0.4907 | Val Acc: 83.66%
# Precision: 0.8397 | Recall: 0.8184 | F1 Score: 0.8264
#
# Epoch 30/50
# Train Loss: 0.4388 | Train Acc: 85.44%
# Val Loss: 0.5085 | Val Acc: 83.51%
# Precision: 0.8318 | Recall: 0.8217 | F1 Score: 0.8255
#
# Epoch 31/50
# Train Loss: 0.4212 | Train Acc: 86.10%
# Val Loss: 0.5368 | Val Acc: 83.16%
# Precision: 0.8572 | Recall: 0.8020 | F1 Score: 0.8240
#
# Epoch 32/50
# Train Loss: 0.4307 | Train Acc: 84.99%
# Val Loss: 0.5362 | Val Acc: 82.89%
# Precision: 0.8383 | Recall: 0.8031 | F1 Score: 0.8166
#
# Epoch 33/50
# Train Loss: 0.4105 | Train Acc: 86.25%
# Val Loss: 0.5759 | Val Acc: 81.67%
# Precision: 0.8177 | Recall: 0.8098 | F1 Score: 0.8102
#
# Epoch 34/50
# Train Loss: 0.4127 | Train Acc: 86.17%
# Val Loss: 0.4773 | Val Acc: 84.77%
# Precision: 0.8542 | Recall: 0.8251 | F1 Score: 0.8367
#
# Epoch 35/50
# Train Loss: 0.3954 | Train Acc: 86.88%
# Val Loss: 0.5102 | Val Acc: 83.24%
# Precision: 0.8303 | Recall: 0.8289 | F1 Score: 0.8268
#
# Epoch 36/50
# Train Loss: 0.3991 | Train Acc: 86.10%
# Val Loss: 0.5047 | Val Acc: 84.15%
# Precision: 0.8350 | Recall: 0.8278 | F1 Score: 0.8295
#
# Epoch 37/50
# Train Loss: 0.4000 | Train Acc: 86.50%
# Val Loss: 0.5135 | Val Acc: 83.81%
# Precision: 0.8354 | Recall: 0.8227 | F1 Score: 0.8278
#
# Epoch 38/50
# Train Loss: 0.3895 | Train Acc: 86.97%
# Val Loss: 0.5122 | Val Acc: 84.73%
# Precision: 0.8584 | Recall: 0.8297 | F1 Score: 0.8411
#
# Epoch 39/50
# Train Loss: 0.3929 | Train Acc: 86.77%
# Val Loss: 0.4838 | Val Acc: 85.34%
# Precision: 0.8470 | Recall: 0.8439 | F1 Score: 0.8439
#
# Epoch 40/50
# Train Loss: 0.3710 | Train Acc: 87.18%
# Val Loss: 0.4797 | Val Acc: 84.27%
# Precision: 0.8368 | Recall: 0.8413 | F1 Score: 0.8385
#
# Epoch 41/50
# Train Loss: 0.3758 | Train Acc: 87.54%
# Val Loss: 0.4619 | Val Acc: 85.41%
# Precision: 0.8486 | Recall: 0.8467 | F1 Score: 0.8470
#
# Epoch 42/50
# Train Loss: 0.3823 | Train Acc: 87.13%
# Val Loss: 0.4900 | Val Acc: 84.12%
# Precision: 0.8471 | Recall: 0.8227 | F1 Score: 0.8317
#
# Epoch 43/50
# Train Loss: 0.3661 | Train Acc: 87.55%
# Val Loss: 0.4895 | Val Acc: 84.73%
# Precision: 0.8558 | Recall: 0.8303 | F1 Score: 0.8414
#
# Epoch 44/50
# Train Loss: 0.3672 | Train Acc: 87.44%
# Val Loss: 0.4656 | Val Acc: 84.69%
# Precision: 0.8356 | Recall: 0.8413 | F1 Score: 0.8379
#
# Epoch 45/50
# Train Loss: 0.3746 | Train Acc: 87.40%
# Val Loss: 0.4623 | Val Acc: 85.53%
# Precision: 0.8534 | Recall: 0.8470 | F1 Score: 0.8494
#
# Epoch 46/50
# Train Loss: 0.3719 | Train Acc: 87.52%
# Val Loss: 0.4965 | Val Acc: 84.08%
# Precision: 0.8434 | Recall: 0.8207 | F1 Score: 0.8293
#
# Epoch 47/50
# Train Loss: 0.3636 | Train Acc: 87.90%
# Val Loss: 0.4659 | Val Acc: 85.57%
# Precision: 0.8477 | Recall: 0.8464 | F1 Score: 0.8461
#
# Epoch 48/50
# Train Loss: 0.3636 | Train Acc: 87.69%
# Val Loss: 0.4861 | Val Acc: 84.96%
# Precision: 0.8407 | Recall: 0.8404 | F1 Score: 0.8397
#
# Epoch 49/50
# Train Loss: 0.3586 | Train Acc: 87.63%
# Val Loss: 0.4985 | Val Acc: 84.84%
# Precision: 0.8455 | Recall: 0.8397 | F1 Score: 0.8420
#
# Epoch 50/50
# Train Loss: 0.3409 | Train Acc: 88.49%
# Val Loss: 0.4686 | Val Acc: 85.07%
# Precision: 0.8456 | Recall: 0.8418 | F1 Score: 0.8424
#
# ######## Training Finished in 5871.178727388382 seconds ###########

# %% [markdown]
# ## Evaluating

# %%
model.eval() 

with torch.no_grad(): 
    correct = 0
    total = 0
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print(f'Test Accuracy of the model on the {total} test images: {(correct / total) * 100:.2f}%')
# Out:
# Test Accuracy of the model on the 2619 test images: 84.35%

# %%
def plot_training(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy')
    plt.plot(epochs, val_accuracies, label='Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.show()

plot_training(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
### Confusion Matrix

# %%
cm = conf_matrix.cpu().numpy()
disp = ConfusionMatrixDisplay(cm, display_labels=classes,)
disp.plot()

# %% [markdown]
# ### Metrics

# %%
precision = MulticlassPrecision(num_classes=num_classes, average=None)
recall = MulticlassRecall(num_classes=num_classes, average=None)
f1_score = MulticlassF1Score(num_classes=num_classes, average=None)


all_preds = []
all_labels = []

model.eval()
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.append(preds.cpu())
        all_labels.append(labels.cpu())


all_preds = torch.cat(all_preds)
all_labels = torch.cat(all_labels)


per_class_precision = precision(all_preds, all_labels)
per_class_recall = recall(all_preds, all_labels)
per_class_f1 = f1_score(all_preds, all_labels)


for i, name in enumerate(classes):
    print(f"Class {i}-{name}: Precision: {per_class_precision[i]:.2f}, Recall: {per_class_recall[i]:.2f}, F1-Score: {per_class_f1[i]:.2f}")
# Out:
# Class 0-butterfly: Precision: 0.89, Recall: 0.92, F1-Score: 0.91
# Class 1-cat: Precision: 0.95, Recall: 0.73, F1-Score: 0.83
# Class 2-cow: Precision: 0.87, Recall: 0.83, F1-Score: 0.85
# Class 3-dog: Precision: 0.90, Recall: 0.91, F1-Score: 0.91
# Class 4-elephant: Precision: 0.88, Recall: 0.90, F1-Score: 0.89
# Class 5-hen: Precision: 0.93, Recall: 0.92, F1-Score: 0.93
# Class 6-horse: Precision: 0.91, Recall: 0.86, F1-Score: 0.88
# Class 7-sheep: Precision: 0.80, Recall: 0.91, F1-Score: 0.86
# Class 8-spider: Precision: 0.95, Recall: 0.94, F1-Score: 0.94
# Class 9-squirrel: Precision: 0.83, Recall: 0.94, F1-Score: 0.88
